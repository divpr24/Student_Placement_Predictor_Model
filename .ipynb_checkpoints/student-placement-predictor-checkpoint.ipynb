# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('students_placement.csv')
df.columns = ['CGPA','IQ', 'Profile_Score', 'Placed']
df.head()
# Out:
#    CGPA   IQ  Profile_Score  Placed
# 0  5.97  106             61       0
# 1  6.83  113             77       0
# 2  6.60  110             61       0
# 3  5.54  113             68       0
# 4  6.84  102             67       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CGPA           300 non-null    float64
#  1   IQ             300 non-null    int64
#  2   Profile_Score  300 non-null    int64
#  3   Placed         300 non-null    int64
# dtypes: float64(1), int64(3)
# memory usage: 9.5 KB

# %%
df.describe()
# Out:
#              CGPA          IQ  Profile_Score      Placed
# count  300.000000  300.000000     300.000000  300.000000
# mean     6.812000  102.570000      60.043333    0.506667
# std      0.971568    8.326034      14.282440    0.500791
# min      4.600000   83.000000      23.000000    0.000000
# 25%      6.010000   96.000000      51.000000    0.000000
# 50%      6.840000  103.500000      60.000000    1.000000
# 75%      7.502500  109.000000      69.000000    1.000000
# max      9.300000  121.000000     100.000000    1.000000

# %% [markdown]
# **Univariate Analysis of the attribute and Target variables.**

# %%
#Univariate Analysis of CGPA.
sns.boxplot(data = df, y = 'CGPA')
plt.show()

# %%
sns.boxplot(data = df, y = 'IQ')
plt.show()

# %%
sns.boxplot(data = df, y = 'Profile_Score')
plt.show()

# %% [markdown]
# **Bivariate Analysis of the Data.**

# %%
#Bivariate Analysis of CGPA with Placed columns.
sns.violinplot(data = df, y = 'CGPA', x = 'Placed')
plt.show()

# %%
#Bivariate Analysis of IQ with Placed columns.
sns.violinplot(data = df, y = 'IQ', x = 'Placed')
plt.show()

# %%
#Bivariate Analysis of Profile_Score with Placed columns.
sns.violinplot(data = df, y = 'Profile_Score', x = 'Placed')
plt.show()

# %%
#Correlation Data
sns.heatmap(data = df.corr(), annot = True, square = True)
plt.show()

# %%
X = df.drop(columns=['placed'])
y = df['placed']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
scaler = StandardScaler()
X_train_trf = scaler.fit_transform(X_train)
X_test_trf = scaler.transform(X_test)
accuracy_score(y_test,
               LogisticRegression()
               .fit(X_train_trf,y_train)
               .predict(X_test_trf))
# Out:
# 0.8833333333333333

# %%
from sklearn.ensemble import RandomForestClassifier
accuracy_score(y_test,RandomForestClassifier().fit(X_train,y_train).predict(X_test))
# Out:
# 0.9

# %%
from sklearn.svm import SVC
accuracy_score(y_test,SVC(kernel='rbf').fit(X_train,y_train).predict(X_test))
# Out:
# 0.9333333333333333

# %%
svc = SVC(kernel='rbf')
svc.fit(X_train,y_train)
# Out:
# SVC()

# %%
rf = RandomForestClassifier()
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
import pickle 
pickle.dump(svc,open('model.pkl','wb'))

# %%
rf.predict(np.array([4.5,56,10]).reshape(1,3))
# Out:
# array([1], dtype=int64)
